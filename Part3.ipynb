# %% [markdown]
# # Movies Tonight Part 3: SQL DML

# %%
# %load_ext sql
# %sql sqlite:///Movies.db
# Out:
# 'Connected: @Movies.db'

# %% [markdown]
# 1. **Load the `DATASET.csv` file into the `Movies.db` database.**
#     - Import the CSV file to create a new table called `DATASET`. Follow the example [here](http://www.sqlitetutorial.net/sqlite-import-csv/).
#     - Use a [`PRAGMA table-info` pseudo-query](https://www.sqlite.org/pragma.html#pragma_table_info) to inspect the design of the new table. [How are we going to handle dates](https://www.sqlite.org/datatype3.html)?

# %%
# %%sql
#
# #Special select query for metadata
# PRAGMA table_info(DATASET);
#
# #Update ShowTime to date
# UPDATE DATASET
#
# strftime('%H:%M')
# Out:
#  * sqlite:///Movies.db
# Done.
# Done.
# [(0, 'TName', 'TEXT', 0, None, 0),
#  (1, 'Location', 'TEXT', 0, None, 0),
#  (2, 'Phone', 'TEXT', 0, None, 0),
#  (3, 'MTitle', 'TEXT', 0, None, 0),
#  (4, 'ShowTime', 'TEXT', 0, None, 0),
#  (5, 'Rating', 'TEXT', 0, None, 0),
#  (6, 'CCode', 'TEXT', 0, None, 0),
#  (7, 'CName', 'TEXT', 0, None, 0)]

# %% [markdown]
# 2. **Populate the tables with data.**
#
#     - Use `INSERT ... SELECT ...` queries to extract data from `DATASET` for each table of your other tables.
#     - Start with the strong entities before moving on to the weak ones. Be sure to always select distinct     values.
#     - Foreign Keys get special treatment. You will have to use JOINs to pick up the PKs from the other side of the relationships. (As in Part 1, use the fact that movie names, theater names, and people names are always unique in our source data. That way you can use then for the JOIN columns.
#     - If you have to start over, then rerun your DDL queries from Part 2.

# %%
# %%sql
# DELETE FROM MOVIE;
# INSERT INTO MOVIE (Title,Rating)
#     SELECT DISTINCT MTitle, Rating
#         FROM DATASET;
#     SELECT * FROM MOVIE;
#
# DELETE FROM THEATER;
# INSERT INTO THEATER (TheaterName,Location,Phone)
#     SELECT DISTINCT TName, Location, Phone
#         FROM DATASET;
#     SELECT * FROM THEATER;
#
# DELETE FROM ARTIST;
# INSERT INTO ARTIST (ArtistName)
#     SELECT DISTINCT CName
#         FROM DATASET;
#         SELECT * FROM ARTIST;
#
# DELETE FROM SHOWTIME;
# INSERT INTO SHOWTIME (ShowTime,MovieID,TheaterID)
# SELECT DISTINCT ShowTime, MOVIE.MovieID, THEATER.TheaterID
# FROM DATASET
#     JOIN MOVIE ON (MOVIE.Title = DATASET.MTitle)
#     JOIN THEATER ON (THEATER.TheaterName = DATASET.TName);
#
# DELETE FROM CREDIT;
# INSERT INTO CREDIT (CCode,ArtistID,ArtistName,MovieID,Title)
# SELECT DISTINCT CCode, ARTIST.ArtistID, ARTIST.ArtistName, MOVIE.MovieID, MOVIE.Title
# FROM DATASET
#     JOIN ARTIST ON (ARTIST.ArtistName = DATASET.CName)
#     JOIN MOVIE ON (MOVIE.Title = DATASET.MTitle);
# SELECT * FROM CREDIT;
# Out:
#  * sqlite:///Movies.db
# 23 rows affected.
# 23 rows affected.
# Done.
# 9 rows affected.
# 9 rows affected.
# Done.
# 153 rows affected.
# 153 rows affected.
# Done.
# 131 rows affected.
# 131 rows affected.
# 162 rows affected.
# 162 rows affected.
# Done.
# [(1, 'A', 1, 'Austin Pendleton', 1, 'Associate, The'),
#  (2, 'A', 2, 'Bebe Neuwirth', 1, 'Associate, The'),
#  (3, 'A', 3, 'Dianne Wiest', 1, 'Associate, The'),
#  (4, 'A', 4, 'Eli Wallach', 1, 'Associate, The'),
#  (5, 'A', 5, 'Kenny Kerr', 1, 'Associate, The'),
#  (6, 'A', 6, 'Lainie Kazan', 1, 'Associate, The'),
#  (7, 'A', 7, 'Tim Daly', 1, 'Associate, The'),
#  (8, 'A', 8, 'Whoopi Goldberg', 1, 'Associate, The'),
#  (9, 'D', 9, 'Donald Petrie', 1, 'Associate, The'),
#  (10, 'A', 10, 'Bernard Hill', 2, 'Ghost & The Darkness, The'),
#  (11, 'A', 11, 'Brian McCardie', 2, 'Ghost & The Darkness, The'),
#  (12, 'A', 12, 'Emily Mortimer', 2, 'Ghost & The Darkness, The'),
#  (13, 'A', 13, 'Henry Cele', 2, 'Ghost & The Darkness, The'),
#  (14, 'A', 14, 'John Kani', 2, 'Ghost & The Darkness, The'),
#  (15, 'A', 15, 'Michael Douglas', 2, 'Ghost & The Darkness, The'),
#  (16, 'A', 16, 'Tom Wilkinson', 2, 'Ghost & The Darkness, The'),
#  (17, 'A', 17, 'Val Kilmer', 2, 'Ghost & The Darkness, The'),
#  (18, 'D', 18, 'Stephen Hopkins', 2, 'Ghost & The Darkness, The'),
#  (19, 'A', 19, 'Bill Pullman', 3, 'Independence Day'),
#  (20, 'A', 20, 'Bill Smitrovich', 3, 'Independence Day'),
#  (21, 'A', 21, 'Harvey Fierstein', 3, 'Independence Day'),
#  (22, 'A', 22, 'Jeff Goldblum', 3, 'Independence Day'),
#  (23, 'A', 23, 'Judd Hirsch', 3, 'Independence Day'),
#  (24, 'A', 24, 'Margaret Colin', 3, 'Independence Day'),
#  (25, 'A', 25, 'Mary McDonnell', 3, 'Independence Day'),
#  (26, 'A', 26, 'Randy Quaid', 3, 'Independence Day'),
#  (27, 'A', 27, 'Robert Loggia', 3, 'Independence Day'),
#  (28, 'A', 28, 'Vivica Fox', 3, 'Independence Day'),
#  (29, 'A', 29, 'Will Smith', 3, 'Independence Day'),
#  (30, 'D', 30, 'Roland Emmerich', 3, 'Independence Day'),
#  (31, 'A', 31, 'Emilio Estevez', 4, 'D3: The Mighty Ducks'),
#  (32, 'A', 32, 'Heidi Kling', 4, 'D3: The Mighty Ducks'),
#  (33, 'A', 33, 'Jeffrey Nordling', 4, 'D3: The Mighty Ducks'),
#  (112, 'A', 77, 'Minnie Driver', 16, 'Big Night'),
#  (113, 'A', 109, 'Stanley Tucci', 16, 'Big Night'),
#  (114, 'A', 110, 'Tony Shalhoub', 16, 'Big Night'),
#  (115, 'D', 106, 'Campbell Scott', 16, 'Big Night'),
#  (116, 'D', 109, 'Stanley Tucci', 16, 'Big Night'),
#  (117, 'A', 111, 'Anna Paquin', 17, 'Fly Away Home'),
#  (118, 'A', 112, 'Dana Delany', 17, 'Fly Away Home'),
#  (119, 'A', 113, 'Jeff Daniels', 17, 'Fly Away Home'),
#  (120, 'D', 114, 'Carroll Ballard', 17, 'Fly Away Home'),
#  (121, 'A', 115, 'Dave Chappelle', 18, 'Nutty Professor, The'),
#  (122, 'A', 116, 'Eddie Murphy', 18, 'Nutty Professor, The'),
#  (123, 'A', 117, 'Jada Pinkett', 18, 'Nutty Professor, The'),
#  (124, 'A', 118, 'James Coburn', 18, 'Nutty Professor, The'),
#  (125, 'A', 119, 'John Ales', 18, 'Nutty Professor, The'),
#  (126, 'A', 120, 'Larry Miller', 18, 'Nutty Professor, The'),
#  (127, 'D', 121, 'Tom Shadyac', 18, 'Nutty Professor, The'),
#  (128, 'A', 122, 'Forest Whitaker', 19, 'Phenomenon'),
#  (129, 'A', 123, 'John Travolta', 19, 'Phenomenon'),
#  (130, 'A', 124, 'Kyra Sedgwick', 19, 'Phenomenon'),
#  (131, 'A', 125, 'Robert Duvall', 19, 'Phenomenon'),
#  (132, 'D', 126, 'Jon Turteltaub', 19, 'Phenomenon'),
#  (133, 'A', 127, 'Blair Underwood', 20, 'Set It Off'),
#  (134, 'A', 117, 'Jada Pinkett', 20, 'Set It Off'),
#  (135, 'A', 128, 'John C. McGinley', 20, 'Set It Off'),
#  (136, 'A', 129, 'Kimberly Elise', 20, 'Set It Off'),
#  (137, 'A', 130, 'Queen Latifah', 20, 'Set It Off'),
#  (138, 'A', 28, 'Vivica Fox', 20, 'Set It Off'),
#  (139, 'D', 131, 'F. Gary Gray', 20, 'Set It Off'),
#  (140, 'A', 132, 'Anthony Hopkins', 21, 'Surviving Picasso'),
#  (141, 'A', 100, 'Diane Venora', 21, 'Surviving Picasso'),
#  (142, 'A', 133, 'Joan Plowright', 21, 'Surviving Picasso'),
#  (143, 'A', 134, 'Julianne Moore', 21, 'Surviving Picasso'),
#  (144, 'A', 135, 'Natascha McElhone', 21, 'Surviving Picasso'),
#  (145, 'D', 136, 'James Ivory', 21, 'Surviving Picasso'),
#  (146, 'A', 137, 'Christine Taylor', 22, 'Very Brady Sequel, A'),
#  (147, 'A', 138, 'Christopher Daniel Barnes', 22, 'Very Brady Sequel, A'),
#  (148, 'A', 139, 'Gary Cole', 22, 'Very Brady Sequel, A'),
#  (149, 'A', 140, 'Henriette Mantel', 22, 'Very Brady Sequel, A'),
#  (150, 'A', 141, 'Jennifer Elise Cox', 22, 'Very Brady Sequel, A'),
#  (151, 'A', 142, 'Jesse Lee', 22, 'Very Brady Sequel, A'),
#  (152, 'A', 143, 'Olivia Hack', 22, 'Very Brady Sequel, A'),
#  (153, 'A', 144, 'Paul Sutera', 22, 'Very Brady Sequel, A'),
#  (154, 'A', 145, 'Shelley Long', 22, 'Very Brady Sequel, A'),
#  (155, 'A', 146, 'Tim Matheson', 22, 'Very Brady Sequel, A'),
#  (156, 'D', 147, 'Arlene Sanford', 22, 'Very Brady Sequel, A'),
#  (157, 'A', 148, 'Joss AcklandDirected by</B> Rob Lieberma', 4, 'D3: The Mighty Ducks'),
#  (158, 'A', 149, 'Ethan Embry', 23, 'That Thing You Do'),
#  (159, 'A', 150, 'Johnathon Schaech', 23, 'That Thing You Do'),
#  (160, 'A', 151, 'Steve Zahn', 23, 'That Thing You Do'),
#  (161, 'A', 152, 'Tom Everett Scott', 23, 'That Thing You Do'),
#  (162, 'D', 153, 'Tom Hanks', 23, 'That Thing You Do')]

# %% [markdown]
# 3. **Check your work.**
# There are 9 theaters, 23 movies, 152 artists, 131 shows, and 161 credits.

# %%
YOUR CODE HERE

# %% [markdown]
# 4. **Now check the source data.**
# There are actually 13 duplicate rows in the original source data! Can you spot them? Write a SQL query that counts how many times each (MTitle, TName, Showtime, CCode, and CName) appears. Which ones appear more than once?

# %%
# %%sql
# SELECT MTitle, TName, ShowTime, CCode, CName, COUNT(*)
# FROM DATASET
# GROUP BY MTitle, TName, ShowTime, CCode, CName
# HAVING COUNT(*) > 1;
# Out:
#  * sqlite:///Movies.db
# Done.
# [('Dear God', 'SOCAL Canyon Springs Cinema', '9:00 PM', 'A', 'Greg Kinnear', 2),
#  ('Dear God', 'SOCAL Canyon Springs Cinema', '9:00 PM', 'A', 'Hector Elizondo', 2),
#  ('Dear God', 'SOCAL Canyon Springs Cinema', '9:00 PM', 'A', 'Jon Seda', 2),
#  ('Dear God', 'SOCAL Canyon Springs Cinema', '9:00 PM', 'A', 'Laurie Metcalf', 2),
#  ('Dear God', 'SOCAL Canyon Springs Cinema', '9:00 PM', 'A', 'Maria Pitillo', 2),
#  ('Dear God', 'SOCAL Canyon Springs Cinema', '9:00 PM', 'A', 'Roscoe Lee Browne', 2),
#  ('Dear God', 'SOCAL Canyon Springs Cinema', '9:00 PM', 'A', 'Tim Conway', 2),
#  ('Dear God', 'SOCAL Canyon Springs Cinema', '9:00 PM', 'D', 'Garry Marshall', 2),
#  ('High School High', 'United Artists Riverside (Galleria) Tyler Mall', '9:00 PM', 'A', 'Jon Lovitz', 2),
#  ('High School High', 'United Artists Riverside (Galleria) Tyler Mall', '9:00 PM', 'A', 'Mekhi Phifer', 2),
#  ('High School High', 'United Artists Riverside (Galleria) Tyler Mall', '9:00 PM', 'A', 'Tia Carrera', 2),
#  ('High School High', 'United Artists Riverside (Galleria) Tyler Mall', '9:00 PM', 'A', 'and Louise Fletcher', 2),
#  ('High School High', 'United Artists Riverside (Galleria) Tyler Mall', '9:00 PM', 'D', 'Hart Bochner', 2)]

# %% [markdown]
# 5. **Drop the `DATASET` table.**
# We don't need it anymore.

# %% [markdown]
# 6. **Save, commit, and push your work to GitHub.**
# Use the commit summary comment "Completed Part 3".
